# %% [markdown]
# <a href="https://colab.research.google.com/github/OxyzGiaHuy/RAG_Langchain_Project/blob/main/%5BTGH%5D_RAG_Langchain_Project_V2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers==4.41.2
# !pip install -q bitsandbytes==0.43.1
# !pip install -q accelerate==0.31.0
# !pip install -q langchain==0.2.5
# !pip install -q langchainhub==0.1.20
# !pip install -q langchain-chroma==0.1.1
# !pip install -q langchain-community==0.2.5
# !pip install -q langchain-openai==0.1.9
# !pip install -q langchain_huggingface==0.0.3
# !pip install -q chainlit==1.1.304
# !pip install -q python-dotenv==1.0.1
# !pip install -q pypdf==4.2.0
# !pip install -q numpy==1.26
# !pip install pyngrok -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 50.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.6/974.6 kB 21.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.4/337.4 kB 32.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.5/127.5 kB 18.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 18.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.5/559.5 kB 14.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 14.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 62.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 92.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 15.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 10.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 34.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 71.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 36.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 11.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 kB 19.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 39.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 85.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 76.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 18.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.4 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 31.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.3/328.3 kB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 39.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 46.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 12.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 kB 7.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 64.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 11.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 57.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 9.0 MB/s eta 0:00:00
#   Building wheel for literalai (setup.py) ... done
#   Building wheel for syncer (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 68.9 MB/s eta 0:00:00

# %%
# %%writefile app.py
# import libraries
import chainlit as cl
import torch

from chainlit.types import AskFileResponse

from transformers import BitsAndBytesConfig
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_huggingface.llms import HuggingFacePipeline

from langchain.memory import ConversationBufferMemory
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_community.document_loaders import PyPDFLoader, TextLoader
from langchain.chains import ConversationalRetrievalChain

from langchain_chroma import Chroma
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain import hub
from pyngrok import ngrok

# initialize Text Splitter and Instance Vectorizaion
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 1000,
                                               chunk_overlap = 100)

embedding = HuggingFaceEmbeddings()


# process input file
def process_file(file: AskFileResponse):
    if file.type == "text/plain":
        Loader = TextLoader
    elif file.type == "application/pdf":
        Loader = PyPDFLoader

    loader = Loader(file.path)
    documents = loader.load()
    docs = text_splitter.split_documents(documents)
    for i, doc in enumerate(docs):
        doc.metadata["source"] = f"source_ {i}"
    return docs


# initialize Chroma database
def get_vector_db(file: AskFileResponse):
    docs = process_file(file)
    cl.user_session.set("docs", docs)
    vector_db = Chroma.from_documents(documents = docs,
                                      embedding = embedding)
    return vector_db

# get llm
def get_huggingface_llm(model_name: str = "lmsys/vicuna-7b-v1.5",
                        max_new_token: int = 512):
    nf4_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_use_double_quant=True,
        bnb_4bit_compute_dtype=torch.bfloat16
    )
    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        quantization_config=nf4_config,
        low_cpu_mem_usage=True
    )
    tokenizer = AutoTokenizer.from_pretrained(model_name)

    model_pipeline = pipeline(
        "text-generation",
        model=model,
        tokenizer=tokenizer,
        max_new_tokens=max_new_token,
        pad_token_id=tokenizer.eos_token_id,
        device_map="auto"
    )

    llm = HuggingFacePipeline(
        pipeline=model_pipeline,
    )
    return llm

LLM = get_huggingface_llm()

# build chainlit
welcome_message = """Welcome to the PDF QA! To get started:
1. Upload a PDF or text file
2. Ask a question about the file
"""

@cl.on_chat_start
async def on_chat_start():
    files = None
    while files is None:
        files = await cl.AskFileMessage(
            content=welcome_message,
            accept=["text/plain", "application/pdf"],
            max_size_mb=20,
            timeout=180,
        ).send()
    file = files[0]

    msg = cl.Message(content=f"Processing `{file.name}`...",
                     disable_feedback=True)
    await msg.send()

    vector_db = await cl.make_async(get_vector_db)(file)

    message_history = ChatMessageHistory()
    memory = ConversationBufferMemory(
        memory_key="chat_history",
        output_key="answer",
        chat_memory=message_history,
        return_messages=True,
    )
    retriever = vector_db.as_retriever(search_type="mmr",
                                       search_kwargs={'k': 3})

    chain = ConversationalRetrievalChain.from_llm(
        llm=LLM,
        chain_type="stuff",
        retriever=retriever,
        memory=memory,
        return_source_documents=True
    )

    msg.content = f"`{file.name}` processed. You can now ask questions!"
    await msg.update()

    cl.user_session.set("chain", chain)


@cl.on_message
async def on_message(message: cl.Message):
    chain = cl.user_session.get("chain")
    cb = cl.AsyncLangchainCallbackHandler()
    res = await chain.ainvoke(message.content, callbacks=[cb])
    answer = res["answer"]
    source_documents = res["source_documents"]
    text_elements = []

    if source_documents:
        for source_idx, source_doc in enumerate(source_documents):
            source_name = f"source_{source_idx}"
            text_elements.append(
                cl.Text(content=source_doc.page_content,
                        name=source_name)
            )
        source_names = [text_el.name for text_el in text_elements]

        if source_names:
            answer += f"\nSources: {', '.join(source_names)}"
        else:
            answer += "\nNo sources found"

    await cl.Message(content=answer, elements=text_elements).send()
# Out:
# Writing app.py

# %%
from pyngrok import ngrok
# !ngrok config add-authtoken 2ipkWlfoUMwqOkYuSxB7PLjHkBj_6vidSqzTVg8mFzHJs3rTA
public_url = ngrok.connect(8000).public_url
print(public_url)
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# https://6d85-34-126-172-62.ngrok-free.app

# %%
# !chainlit run app.py
# Out:
# 2024-07-05 16:28:11 - Created default config file at /content/.chainlit/config.toml
# 2024-07-05 16:28:11 - Created default translation directory at /content/.chainlit/translations
# 2024-07-05 16:28:11 - Created default translation file at /content/.chainlit/translations/en-US.json
# 2024-07-05 16:28:22.205251: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-05 16:28:22.205300: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-05 16:28:22.339937: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-05 16:28:22.586123: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-05 16:28:24.664368: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-07-05 16:28:33 - Use pytorch device_name: cuda
# 2024-07-05 16:28:33 - Load pretrained SentenceTransformer: sentence-transformers/all-mpnet-base-v2
# modules.json: 100% 349/349 [00:00<00:00, 1.62MB/s]
# config_sentence_transformers.json: 100% 116/116 [00:00<00:00, 657kB/s]
# README.md: 100% 10.6k/10.6k [00:00<00:00, 36.2MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 291kB/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json: 100% 571/571 [00:00<00:00, 2.87MB/s]
# model.safetensors: 100% 438M/438M [00:01<00:00, 226MB/s]
# tokenizer_config.json: 100% 363/363 [00:00<00:00, 2.58MB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 50.8MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 25.3MB/s]
# special_tokens_map.json: 100% 239/239 [00:00<00:00, 1.58MB/s]
# 1_Pooling/config.json: 100% 190/190 [00:00<00:00, 1.27MB/s]
# config.json: 100% 615/615 [00:00<00:00, 4.15MB/s]
# pytorch_model.bin.index.json: 100% 26.8k/26.8k [00:00<00:00, 117MB/s]
# Downloading shards:   0% 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0% 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00001-of-00002.bin:   0% 41.9M/9.98G [00:00<00:29, 342MB/s]
# pytorch_model-00001-of-00002.bin:   1% 94.4M/9.98G [00:00<00:23, 418MB/s]
# pytorch_model-00001-of-00002.bin:   1% 147M/9.98G [00:00<00:30, 326MB/s]
# pytorch_model-00001-of-00002.bin:   2% 189M/9.98G [00:00<00:36, 272MB/s]
# pytorch_model-00001-of-00002.bin:   2% 220M/9.98G [00:00<00:37, 261MB/s]
# pytorch_model-00001-of-00002.bin:   3% 252M/9.98G [00:00<00:36, 267MB/s]
# pytorch_model-00001-of-00002.bin:   3% 283M/9.98G [00:01<00:38, 253MB/s]
# pytorch_model-00001-of-00002.bin:   3% 315M/9.98G [00:01<00:42, 227MB/s]
# pytorch_model-00001-of-00002.bin:   4% 357M/9.98G [00:01<00:37, 254MB/s]
# pytorch_model-00001-of-00002.bin:   4% 388M/9.98G [00:01<00:38, 246MB/s]
# pytorch_model-00001-of-00002.bin:   4% 419M/9.98G [00:01<00:38, 250MB/s]
# pytorch_model-00001-of-00002.bin:   5% 451M/9.98G [00:01<00:37, 256MB/s]
# pytorch_model-00001-of-00002.bin:   5% 482M/9.98G [00:01<00:38, 249MB/s]
# pytorch_model-00001-of-00002.bin:   5% 514M/9.98G [00:02<00:43, 220MB/s]
# pytorch_model-00001-of-00002.bin:   5% 545M/9.98G [00:02<00:44, 212MB/s]
# pytorch_model-00001-of-00002.bin:   6% 577M/9.98G [00:02<00:42, 220MB/s]
# pytorch_model-00001-of-00002.bin:   6% 608M/9.98G [00:02<00:42, 221MB/s]
# pytorch_model-00001-of-00002.bin:   6% 640M/9.98G [00:02<00:40, 228MB/s]
# pytorch_model-00001-of-00002.bin:   7% 671M/9.98G [00:02<00:41, 225MB/s]
# pytorch_model-00001-of-00002.bin:   7% 703M/9.98G [00:02<00:39, 233MB/s]
# pytorch_model-00001-of-00002.bin:   7% 734M/9.98G [00:02<00:37, 249MB/s]
# pytorch_model-00001-of-00002.bin:   8% 765M/9.98G [00:03<00:37, 244MB/s]
# pytorch_model-00001-of-00002.bin:   8% 807M/9.98G [00:03<00:34, 268MB/s]
# pytorch_model-00001-of-00002.bin:   8% 839M/9.98G [00:03<00:38, 238MB/s]
# pytorch_model-00001-of-00002.bin:   9% 870M/9.98G [00:03<00:38, 235MB/s]
# pytorch_model-00001-of-00002.bin:   9% 902M/9.98G [00:03<00:41, 220MB/s]
# pytorch_model-00001-of-00002.bin:   9% 933M/9.98G [00:03<00:41, 215MB/s]
# pytorch_model-00001-of-00002.bin:  10% 965M/9.98G [00:03<00:41, 215MB/s]
# pytorch_model-00001-of-00002.bin:  96% 9.53G/9.98G [00:51<00:03, 142MB/s]
# pytorch_model-00001-of-00002.bin:  96% 9.56G/9.98G [00:51<00:02, 163MB/s]
# pytorch_model-00001-of-00002.bin:  96% 9.59G/9.98G [00:51<00:02, 173MB/s]
# pytorch_model-00001-of-00002.bin:  96% 9.63G/9.98G [00:52<00:01, 195MB/s]
# pytorch_model-00001-of-00002.bin:  97% 9.66G/9.98G [00:52<00:01, 209MB/s]
# pytorch_model-00001-of-00002.bin:  97% 9.69G/9.98G [00:52<00:01, 219MB/s]
# pytorch_model-00001-of-00002.bin:  97% 9.72G/9.98G [00:52<00:01, 237MB/s]
# pytorch_model-00001-of-00002.bin:  98% 9.75G/9.98G [00:54<00:05, 44.0MB/s]
# pytorch_model-00001-of-00002.bin:  98% 9.80G/9.98G [00:54<00:02, 70.1MB/s]
# pytorch_model-00001-of-00002.bin:  99% 9.85G/9.98G [00:54<00:01, 94.7MB/s]
# pytorch_model-00001-of-00002.bin:  99% 9.88G/9.98G [00:54<00:00, 114MB/s]
# pytorch_model-00001-of-00002.bin:  99% 9.91G/9.98G [00:54<00:00, 134MB/s]
# pytorch_model-00001-of-00002.bin: 100% 9.98G/9.98G [00:55<00:00, 181MB/s]
# Downloading shards:  50% 1/2 [00:55<00:55, 55.46s/it]
# pytorch_model-00002-of-00002.bin:   0% 0.00/3.50G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   1% 41.9M/3.50G [00:00<00:09, 381MB/s]
# pytorch_model-00002-of-00002.bin:   2% 83.9M/3.50G [00:00<00:08, 382MB/s]
# pytorch_model-00002-of-00002.bin:   4% 126M/3.50G [00:00<00:12, 261MB/s]
# pytorch_model-00002-of-00002.bin:   4% 157M/3.50G [00:00<00:14, 235MB/s]
# pytorch_model-00002-of-00002.bin:   5% 189M/3.50G [00:03<01:36, 34.5MB/s]
# pytorch_model-00002-of-00002.bin:   7% 231M/3.50G [00:03<01:02, 52.2MB/s]
# pytorch_model-00002-of-00002.bin:   8% 273M/3.50G [00:03<00:43, 74.5MB/s]
# pytorch_model-00002-of-00002.bin:   9% 304M/3.50G [00:03<00:34, 92.2MB/s]
# pytorch_model-00002-of-00002.bin:  10% 336M/3.50G [00:03<00:28, 112MB/s]
# pytorch_model-00002-of-00002.bin:  10% 367M/3.50G [00:03<00:23, 136MB/s]
# pytorch_model-00002-of-00002.bin:  11% 398M/3.50G [00:04<00:23, 133MB/s]
# pytorch_model-00002-of-00002.bin:  12% 430M/3.50G [00:04<00:23, 131MB/s]
# pytorch_model-00002-of-00002.bin:  13% 451M/3.50G [00:04<00:23, 132MB/s]
# pytorch_model-00002-of-00002.bin:  13% 472M/3.50G [00:04<00:23, 129MB/s]
# pytorch_model-00002-of-00002.bin:  14% 493M/3.50G [00:04<00:21, 141MB/s]
# pytorch_model-00002-of-00002.bin:  15% 524M/3.50G [00:04<00:17, 175MB/s]
# pytorch_model-00002-of-00002.bin:  16% 556M/3.50G [00:05<00:46, 62.8MB/s]
# pytorch_model-00002-of-00002.bin:  16% 577M/3.50G [00:07<01:25, 34.0MB/s]
# pytorch_model-00002-of-00002.bin:  17% 608M/3.50G [00:07<01:01, 47.2MB/s]
# pytorch_model-00002-of-00002.bin:  19% 650M/3.50G [00:07<00:39, 71.6MB/s]
# pytorch_model-00002-of-00002.bin:  19% 682M/3.50G [00:07<00:30, 91.0MB/s]
# pytorch_model-00002-of-00002.bin:  20% 713M/3.50G [00:07<00:24, 115MB/s]
# pytorch_model-00002-of-00002.bin:  21% 744M/3.50G [00:08<00:20, 137MB/s]
# pytorch_model-00002-of-00002.bin:  22% 786M/3.50G [00:08<00:15, 173MB/s]
# pytorch_model-00002-of-00002.bin:  24% 828M/3.50G [00:08<00:12, 207MB/s]
# pytorch_model-00002-of-00002.bin:  25% 870M/3.50G [00:08<00:11, 237MB/s]
# pytorch_model-00002-of-00002.bin:  26% 912M/3.50G [00:08<00:09, 260MB/s]
# pytorch_model-00002-of-00002.bin:  27% 944M/3.50G [00:08<00:09, 262MB/s]
# pytorch_model-00002-of-00002.bin:  28% 986M/3.50G [00:08<00:09, 278MB/s]
# pytorch_model-00002-of-00002.bin:  29% 1.02G/3.50G [00:08<00:08, 282MB/s]
# pytorch_model-00002-of-00002.bin:  30% 1.06G/3.50G [00:09<00:08, 295MB/s]
# pytorch_model-00002-of-00002.bin:  31% 1.09G/3.50G [00:09<00:08, 287MB/s]
# pytorch_model-00002-of-00002.bin:  32% 1.12G/3.50G [00:11<00:49, 47.7MB/s]
# pytorch_model-00002-of-00002.bin:  33% 1.15G/3.50G [00:11<00:39, 59.4MB/s]
# pytorch_model-00002-of-00002.bin:  34% 1.17G/3.50G [00:11<00:33, 68.7MB/s]
# pytorch_model-00002-of-00002.bin:  35% 1.22G/3.50G [00:11<00:23, 98.5MB/s]
# pytorch_model-00002-of-00002.bin:  36% 1.26G/3.50G [00:11<00:17, 128MB/s]
# pytorch_model-00002-of-00002.bin:  37% 1.29G/3.50G [00:12<00:15, 147MB/s]
# pytorch_model-00002-of-00002.bin:  38% 1.32G/3.50G [00:12<00:12, 170MB/s]
# pytorch_model-00002-of-00002.bin:  39% 1.36G/3.50G [00:12<00:10, 203MB/s]
# pytorch_model-00002-of-00002.bin:  40% 1.41G/3.50G [00:12<00:09, 232MB/s]
# pytorch_model-00002-of-00002.bin:  41% 1.45G/3.50G [00:12<00:08, 253MB/s]
# pytorch_model-00002-of-00002.bin:  42% 1.48G/3.50G [00:12<00:08, 250MB/s]
# pytorch_model-00002-of-00002.bin:  43% 1.51G/3.50G [00:12<00:07, 249MB/s]
# pytorch_model-00002-of-00002.bin:  44% 1.55G/3.50G [00:12<00:07, 257MB/s]
# pytorch_model-00002-of-00002.bin:  45% 1.58G/3.50G [00:13<00:07, 248MB/s]
# pytorch_model-00002-of-00002.bin:  46% 1.61G/3.50G [00:13<00:07, 240MB/s]
# pytorch_model-00002-of-00002.bin:  47% 1.65G/3.50G [00:13<00:07, 233MB/s]
# pytorch_model-00002-of-00002.bin:  48% 1.68G/3.50G [00:13<00:08, 226MB/s]
# pytorch_model-00002-of-00002.bin:  49% 1.71G/3.50G [00:13<00:07, 226MB/s]
# pytorch_model-00002-of-00002.bin:  50% 1.74G/3.50G [00:13<00:07, 233MB/s]
# pytorch_model-00002-of-00002.bin:  51% 1.77G/3.50G [00:13<00:07, 230MB/s]
# pytorch_model-00002-of-00002.bin:  52% 1.80G/3.50G [00:14<00:07, 233MB/s]
# pytorch_model-00002-of-00002.bin:  52% 1.84G/3.50G [00:14<00:07, 230MB/s]
# pytorch_model-00002-of-00002.bin:  53% 1.87G/3.50G [00:14<00:06, 241MB/s]
# pytorch_model-00002-of-00002.bin:  54% 1.90G/3.50G [00:14<00:06, 248MB/s]
# pytorch_model-00002-of-00002.bin:  55% 1.93G/3.50G [00:14<00:06, 256MB/s]
# pytorch_model-00002-of-00002.bin:  56% 1.96G/3.50G [00:14<00:06, 252MB/s]
# pytorch_model-00002-of-00002.bin:  57% 1.99G/3.50G [00:14<00:06, 247MB/s]
# pytorch_model-00002-of-00002.bin:  58% 2.02G/3.50G [00:14<00:05, 248MB/s]
# pytorch_model-00002-of-00002.bin:  59% 2.06G/3.50G [00:15<00:05, 249MB/s]
# pytorch_model-00002-of-00002.bin:  60% 2.09G/3.50G [00:15<00:05, 241MB/s]
# pytorch_model-00002-of-00002.bin:  61% 2.13G/3.50G [00:15<00:05, 259MB/s]
# pytorch_model-00002-of-00002.bin:  62% 2.16G/3.50G [00:15<00:05, 259MB/s]
# pytorch_model-00002-of-00002.bin:  63% 2.19G/3.50G [00:15<00:05, 243MB/s]
# pytorch_model-00002-of-00002.bin:  64% 2.22G/3.50G [00:15<00:05, 242MB/s]
# pytorch_model-00002-of-00002.bin:  64% 2.25G/3.50G [00:15<00:05, 233MB/s]
# pytorch_model-00002-of-00002.bin:  65% 2.29G/3.50G [00:16<00:05, 240MB/s]
# pytorch_model-00002-of-00002.bin:  66% 2.32G/3.50G [00:16<00:04, 241MB/s]
# pytorch_model-00002-of-00002.bin:  67% 2.35G/3.50G [00:16<00:04, 251MB/s]
# pytorch_model-00002-of-00002.bin:  68% 2.38G/3.50G [00:16<00:04, 230MB/s]
# pytorch_model-00002-of-00002.bin:  69% 2.41G/3.50G [00:16<00:04, 227MB/s]
# pytorch_model-00002-of-00002.bin:  70% 2.44G/3.50G [00:16<00:04, 238MB/s]
# pytorch_model-00002-of-00002.bin:  71% 2.47G/3.50G [00:16<00:04, 234MB/s]
# pytorch_model-00002-of-00002.bin:  72% 2.51G/3.50G [00:16<00:04, 230MB/s]
# pytorch_model-00002-of-00002.bin:  72% 2.54G/3.50G [00:17<00:03, 243MB/s]
# pytorch_model-00002-of-00002.bin:  73% 2.57G/3.50G [00:17<00:03, 254MB/s]
# pytorch_model-00002-of-00002.bin:  74% 2.60G/3.50G [00:17<00:03, 249MB/s]
# pytorch_model-00002-of-00002.bin:  75% 2.63G/3.50G [00:17<00:03, 250MB/s]
# pytorch_model-00002-of-00002.bin:  76% 2.67G/3.50G [00:17<00:03, 261MB/s]
# pytorch_model-00002-of-00002.bin:  77% 2.71G/3.50G [00:17<00:02, 267MB/s]
# pytorch_model-00002-of-00002.bin:  78% 2.74G/3.50G [00:17<00:03, 249MB/s]
# pytorch_model-00002-of-00002.bin:  79% 2.77G/3.50G [00:17<00:02, 249MB/s]
# pytorch_model-00002-of-00002.bin:  80% 2.81G/3.50G [00:18<00:02, 273MB/s]
# pytorch_model-00002-of-00002.bin:  81% 2.85G/3.50G [00:18<00:02, 302MB/s]
# pytorch_model-00002-of-00002.bin:  82% 2.88G/3.50G [00:18<00:02, 295MB/s]
# pytorch_model-00002-of-00002.bin:  84% 2.93G/3.50G [00:18<00:01, 305MB/s]
# pytorch_model-00002-of-00002.bin:  85% 2.97G/3.50G [00:18<00:01, 299MB/s]
# pytorch_model-00002-of-00002.bin:  86% 3.01G/3.50G [00:18<00:01, 307MB/s]
# pytorch_model-00002-of-00002.bin:  87% 3.05G/3.50G [00:18<00:01, 328MB/s]
# pytorch_model-00002-of-00002.bin:  88% 3.09G/3.50G [00:19<00:01, 224MB/s]
# pytorch_model-00002-of-00002.bin:  90% 3.14G/3.50G [00:19<00:01, 260MB/s]
# pytorch_model-00002-of-00002.bin:  90% 3.17G/3.50G [00:19<00:01, 263MB/s]
# pytorch_model-00002-of-00002.bin:  91% 3.20G/3.50G [00:19<00:01, 272MB/s]
# pytorch_model-00002-of-00002.bin:  93% 3.24G/3.50G [00:19<00:00, 287MB/s]
# pytorch_model-00002-of-00002.bin:  94% 3.28G/3.50G [00:19<00:00, 299MB/s]
# pytorch_model-00002-of-00002.bin:  95% 3.32G/3.50G [00:19<00:00, 308MB/s]
# pytorch_model-00002-of-00002.bin:  96% 3.37G/3.50G [00:20<00:00, 299MB/s]
# pytorch_model-00002-of-00002.bin:  97% 3.40G/3.50G [00:20<00:00, 255MB/s]
# pytorch_model-00002-of-00002.bin:  98% 3.44G/3.50G [00:20<00:00, 274MB/s]
# pytorch_model-00002-of-00002.bin:  99% 3.47G/3.50G [00:20<00:00, 272MB/s]
# pytorch_model-00002-of-00002.bin: 100% 3.50G/3.50G [00:20<00:00, 170MB/s]
# Downloading shards: 100% 2/2 [01:16<00:00, 38.16s/it]
# Loading checkpoint shards: 100% 2/2 [00:55<00:00, 27.73s/it]
# generation_config.json: 100% 162/162 [00:00<00:00, 1.19MB/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# tokenizer_config.json: 100% 749/749 [00:00<00:00, 3.79MB/s]
# tokenizer.model: 100% 500k/500k [00:00<00:00, 301MB/s]
# special_tokens_map.json: 100% 438/438 [00:00<00:00, 2.24MB/s]
# 2024-07-05 16:31:01 - Created default chainlit markdown file at /content/chainlit.md
# 2024-07-05 16:31:01 - Your app is available at http://localhost:8000
# 2024-07-05 16:32:03 - Translation file for vi-VN not found. Using default translation en-US.
# 2024-07-05 16:32:04 - Translated markdown file for vi-VN not found. Defaulting to chainlit.md.
# 2024-07-05 16:33:35 - Translation file for vi-VN not found. Using default translation en-US.
# 2024-07-05 16:33:40 - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
